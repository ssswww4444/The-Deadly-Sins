# %%
import pandas as pd
import os
import json
import matplotlib.pyplot as plt
from collections import defaultdict

# %% [markdown]
# Aurin Data

# %%
# aurin
with open("homeless.json") as f:
    homeless = json.load(f)
    
with open("child.json") as f:
    child = json.load(f)
    
with open("unemployment.json") as f:
    unemployment = json.load(f)
    
with open("satisfaction.json") as f:
    satisfaction = json.load(f)
    
with open("education.json") as f:
    education = json.load(f)
    
with open("hour.json") as f: 
    hour = json.load(f)
    
with open("people.json") as f:
    people = json.load(f)
    
with open("median_income.json") as f:
    income = json.load(f)
    
with open("overtime_age.json") as f:
    overtime_age = json.load(f)

# %%
# read aurin data
df2 = pd.DataFrame.from_records(list(map(lambda x: x["properties"], hour["features"])))
df3 = pd.DataFrame.from_records(list(map(lambda x: x["properties"], homeless["features"])))
df4 = pd.DataFrame.from_records(list(map(lambda x: x["properties"], unemployment["features"])))
df5 = pd.DataFrame.from_records(list(map(lambda x: x["properties"], satisfaction["features"])))
df6 = pd.DataFrame.from_records(list(map(lambda x: x["properties"], education["features"])))
df7 = pd.DataFrame.from_records(list(map(lambda x: x["properties"], people["features"])))
df8 = pd.DataFrame.from_records(list(map(lambda x: x["properties"], income["features"])))

# %% [markdown]
# Twitter Data from 3 databases

# %%
with open("../spark_results.json", "r") as f:
    big_twitter = json.load(f)["rows"][0]["doc"]
    
with open("../spark_results.json", "r") as f:
    big_twitter_polarity = json.load(f)["rows"][1]["doc"]["polarity"]
    
with open("../spark_results.json", "r") as f:
    richard_db = json.load(f)["rows"][5]["doc"]
    
with open("../spark_results.json", "r") as f:
    richard_db_polarity = json.load(f)["rows"][6]["doc"]["polarity"]
    
with open("../spark_results.json", "r") as f:
    twitter = json.load(f)["rows"][9]["doc"]
    
with open("../spark_results.json", "r") as f:
    twitter_polarity = json.load(f)["rows"][10]["doc"]["polarity"]

# %%
big_twitter.keys()
# Out:
# dict_keys(['_id', '_rev', 'tweets_num', 'total_info', 'negative_tweets_num', 'negative_word_freq', 'negative_info', 'neutral_tweets_num', 'neutral_word_freq', 'neutral_info', 'anger_tweets_num', 'anger_word_freq', 'anger_info', 'amusement_tweets_num', 'amusement_word_freq', 'amusement_info', 'annoyance_tweets_num', 'annoyance_word_freq', 'annoyance_info', 'negative_fear_tweets_num', 'negative_fear_word_freq', 'negative_fear_info', 'indifference_tweets_num', 'indifference_word_freq', 'indifference_info', 'joy_tweets_num', 'joy_word_freq', 'joy_info', 'awe_tweets_num', 'awe_word_freq', 'awe_info', 'sadness_tweets_num', 'sadness_word_freq', 'sadness_info'])

# %%
def make_df(data_ls):
    
    code_ls = data_ls[0]["total_info"].keys()
    records = []
    
    for code in code_ls:
        record = defaultdict(int)
        
        record["sa2_main16"] = code
        
        for data in data_ls:
            record["total_tweet"] += data["total_info"].get(code,0)
            
            # sentiment
            record["negative_tweet"] += data["negative_info"].get(code,0)
            record["neutral_tweet"] += data["neutral_info"].get(code,0)
            
            # emotion
            record["anger_tweet"] += data["anger_info"].get(code,0)
            record["amusement_tweet"] += data["amusement_info"].get(code,0)
            record["annoyance_tweet"] += data["annoyance_info"].get(code,0)
            record["fear_tweet"] += data["negative_fear_info"].get(code,0)
            record["indifference_tweet"] += data["indifference_info"].get(code,0)
            record["joy_tweet"] += data["joy_info"].get(code,0)
            record["awe_tweet"] += data["awe_info"].get(code,0)
            record["sad_tweet"] += data["sadness_info"].get(code, 0)
        records.append(record)

    df = pd.DataFrame.from_records(records)
    
    return df

# %%
df1 = make_df([big_twitter, richard_db, twitter])
df1.head()
# Out:
#    amusement_tweet  anger_tweet  annoyance_tweet  awe_tweet  fear_tweet  \
# 0              281           40               51        749          20
# 1             2061          169              175       5610          56
# 2              254           31               41        479          12
# 3              267           33               62        987          15
# 4             1750          813              151       5947          71
#
#    indifference_tweet  joy_tweet  negative_tweet  neutral_tweet sa2_main16  \
# 0                  58          6             196            594  208031190
# 1                 461         44             826           4139  206061137
# 2                  55          4             147            430  211041270
# 3                  72         20             192            755  212051322
# 4                 350         59             949           5128  206041117
#
#    sad_tweet  total_tweet
# 0          4         1228
# 1         63         8716
# ...

# %%
df1["wrath_rate(%)"] = (df1["anger_tweet"] + df1["annoyance_tweet"])/ df1["total_tweet"]*100
df1["negative_rate(%)"] = df1["negative_tweet"] / df1["total_tweet"]*100
df1 = df1.loc[:, ["sa2_main16", "wrath_rate(%)", "negative_rate(%)"]]

# %%
df1.head()
# Out:
#   sa2_main16  wrath_rate(%)  negative_rate(%)
# 0  208031190       7.410423         15.960912
# 1  206061137       3.946765          9.476824
# 2  211041270       8.017817         16.369710
# 3  212051322       6.414585         12.964213
# 4  206041117      10.341129         10.180219

# %%
df2["work_overtime(%)"] = (df2["p_tot_41_48"] + df2["p_tot_49over"]) / (df2["p_tot_tot"] - df2["p_tot_hours_ns"] - df2["p_tot_0"])*100
df2 = df2.loc[:,["sa2_main16", "work_overtime(%)"]]
df2.head()
# Out:
#   sa2_main16  work_overtime(%)
# 0  213051466         21.008403
# 1  206061136         34.802665
# 2  206071141         32.650790
# 3  210031440         20.995025
# 4  210041240         23.914851

# %%
df3.head()  # no need to handle
# Out:
#    hl_p_homeless_tot sa2_main16
# 0                223  206071142
# 1                100  212031302
# 2                 73  206061136
# 3                 95  206071141
# 4                 49  210031440

# %%
df4["unemp_rate(%)"] = df4["p_tot_unemp_total"]/df4["p_tot_tot"]*100
df4 = df4.loc[:,["sa2_main16", "unemp_rate(%)"]]
df4.head()
# Out:
#   sa2_main16  unemp_rate(%)
# 0  206061136       3.246608
# 1  206071141       4.735932
# 2  210031440       4.063797
# 3  210041240       4.152841
# 4  210041241       4.004550

# %%
df5["sa2_main16"] = df5["sa2_code16"]
df5["high_satisfaction_rate(%)"] = df5["life_satisfaction_pc_80_to_100_synth"]*100
df5 = df5.loc[:,["sa2_main16", "high_satisfaction_rate(%)"]]
df5.head()
# Out:
#   sa2_main16  high_satisfaction_rate(%)
# 0  206061136                    64.7118
# 1  206071141                    61.3216
# 2  210031440                    62.3543
# 3  210041240                    66.8407
# 4  210041241                    65.1980

# %%
df6["complete_y12_rate(%)"] = df6["p_y12e_tot"]/(df6["m_tot_tot"] + df6["f_tot_tot"])*100
df6 = df6.loc[:,["sa2_main16", "complete_y12_rate(%)"]]
df6.head()
# Out:
#   sa2_main16  complete_y12_rate(%)
# 0  206061136             74.319796
# 1  206071141             70.348837
# 2  210031440             47.283474
# 3  210041241             49.113220
# 4  210041240             49.388493

# %%
df7_renamed = df7.rename(columns={"births_dth_births_p_num": "birth_num", 
                                  "births_dth_dth_p_num": "death_num", 
                                  "births_dth_stnd_death_rt_per_1000_pop_p_rate": "death_rate(%)", 
                                  "births_dth_tot_fert_rt_per_f_p_rate": "fertility_rate(%)",
                                  "est_res_pop_med_age_usual_res_erp_30_jun_p_yrs": "median_age",
                                  "est_res_pop_p_tot_num": "population",
                                  "est_res_pop_p_wrking_age_pop_15_64_yrs_pr100": "working_age_rate(%)",
                                  "sa2_code16": "sa2_main16"})

df7 = df7_renamed.loc[:,["sa2_main16", "death_rate(%)", "population", "median_age"]]
df7.head()
# Out:
#   sa2_main16  death_rate(%)  population  median_age
# 0  206061136            5.7     21275.0        33.2
# 1  210031440            3.9      5911.0        38.2
# 2  210041240            5.3     13238.0        38.1
# 3  208021180            4.9      8038.0        35.0
# 4  213051466            NaN     15147.0        31.5

# %%
df8 = df8.rename(columns={"sa2_code_2016":"sa2_main16"})
df8.head()
# Out:
#    median_aud_2014_15 sa2_main16
# 0                 NaN  208031192
# 1               112.0  209011197
# 2               166.0  206061136
# 3               108.0  206071141
# 4               173.0  210031440

# %%
print(len(df1))
print(len(df2))
print(len(df3))
print(len(df4))
print(len(df5))
print(len(df7))
print(len(df8))
# Out:
# 305
# 309
# 309
# 309
# 309
# 309
# 309

# %%
combined_df = df1.merge(df2).merge(df3).merge(df4).merge(df6).merge(df7).merge(df8)

# %%
combined_df.head()
# Out:
#   sa2_main16  wrath_rate(%)  negative_rate(%)  work_overtime(%)  \
# 0  208031190       7.410423         15.960912         27.042432
# 1  206061137       3.946765          9.476824         33.103104
# 2  211041270       8.017817         16.369710         22.898810
# 3  212051322       6.414585         12.964213         19.700187
# 4  206041117      10.341129         10.180219         23.791040
#
#    hl_p_homeless_tot  unemp_rate(%)  complete_y12_rate(%)  death_rate(%)  \
# 0                 18       3.501281             66.613924            4.2
# 1                 67       3.810356             77.285290            3.9
# 2                 56       3.709176             68.923625            3.6
# 3                 45       4.493137             72.823668            4.1
# 4                129       8.639594             78.495526            5.0
#
#    population  median_age  median_aud_2014_15
# 0     13695.0        40.9               153.0
# 1     22350.0        31.8               240.0
# ...

# %%
combined_df.corr()
# Out:
#                       wrath_rate(%)  negative_rate(%)  work_overtime(%)  \
# wrath_rate(%)              1.000000         -0.107345         -0.310599
# negative_rate(%)          -0.107345          1.000000         -0.005402
# work_overtime(%)          -0.310599         -0.005402          1.000000
# hl_p_homeless_tot          0.069079         -0.002122         -0.236252
# unemp_rate(%)              0.230441          0.041415         -0.666690
# complete_y12_rate(%)      -0.076227          0.023012          0.353207
# death_rate(%)              0.076944          0.048451         -0.287477
# population                -0.001023          0.025404         -0.137960
# median_age                -0.036280         -0.053212          0.276929
# median_aud_2014_15        -0.104909         -0.084281          0.573969
#
#                       hl_p_homeless_tot  unemp_rate(%)  complete_y12_rate(%)  \
# wrath_rate(%)                  0.069079       0.230441             -0.076227
# ...

# %%
combined_df.corr().iloc[0, 1:]
# Out:
# negative_rate(%)       -0.107345
# work_overtime(%)       -0.310599
# hl_p_homeless_tot       0.069079
# unemp_rate(%)           0.230441
# complete_y12_rate(%)   -0.076227
# death_rate(%)           0.076944
# population             -0.001023
# median_age             -0.036280
# median_aud_2014_15     -0.104909
# Name: wrath_rate(%), dtype: float64

# %%
combined_df.corr().iloc[1, 2:]
# Out:
# work_overtime(%)       -0.005402
# hl_p_homeless_tot      -0.002122
# unemp_rate(%)           0.041415
# complete_y12_rate(%)    0.023012
# death_rate(%)           0.048451
# population              0.025404
# median_age             -0.053212
# median_aud_2014_15     -0.084281
# Name: negative_rate(%), dtype: float64

# %%
combined_df["wrath_rate(%)"].corr(combined_df["work_overtime(%)"], method="pearson")
# Out:
# -0.31059851211405176

# %%
plt.scatter(combined_df["wrath_rate(%)"],
            combined_df["hl_p_homeless_tot"])
plt.xlabel('hl_p_homeless_tot')
plt.ylabel('wrath_rate')
# Out:
# Text(0, 0.5, 'wrath_rate')

# %% [markdown]
# # OUTPUT FOR FRONT END

# %%
out_dict = {}
code_ls = big_twitter["total_info"].keys()

for code in code_ls:
    
    row = df1[df1["sa2_main16"] == code]
    
    out_dict[code] = {
        "sa2_main16": code,
        "total_tweet": row["total_tweet"].values[0],
        # sentiment
        "negative_tweet": row["negative_tweet"].values[0],
        "neutral_tweet": row["neutral_tweet"].values[0],
        "positive_tweet": row["total_tweet"].values[0] - row["negative_tweet"].values[0] - row["neutral_tweet"].values[0],
        # emotion
        "anger_tweet": row["anger_tweet"].values[0],
        "amusement_tweet": row["amusement_tweet"].values[0],
        "annoyance_tweet": row["annoyance_tweet"].values[0],
        "fear_tweet": row["fear_tweet"].values[0],
        "indifference_tweet": row["indifference_tweet"].values[0],
        "joy_tweet": row["joy_tweet"].values[0],
        "awe_tweet": row["awe_tweet"].values[0],
        "sad_tweet": row["sad_tweet"].values[0]
    }

# %% [markdown]
# # PIE-CHART

# %%
pie_dict = {}
region_dict = {"Melbourne": "206041122",
               "Docklands": "206041118",
               "Southbank": "206041126",
               "East Melbourne": "206041119",
               "Kensington": "206041121"}

for region, code in region_dict.items():
    out_region = out_dict[code]
    pie_dict[region] = {"total_tweet": int(out_region["total_tweet"]),
                        "anger_tweet": int(out_region["anger_tweet"]),
                        "amusement_tweet": int(out_region["amusement_tweet"]),
                        "fear_tweet": int(out_region["fear_tweet"]),
                        "indifference_tweet": int(out_region["indifference_tweet"]),
                        "joy_tweet": int(out_region["joy_tweet"]),
                        "awe_tweet": int(out_region["awe_tweet"]),
                        "sad_tweet": int(out_region["sad_tweet"])}

# %%
pie_dict
# Out:
# {'Melbourne': {'total_tweet': 117260,
#   'anger_tweet': 1869,
#   'amusement_tweet': 22310,
#   'fear_tweet': 1234,
#   'indifference_tweet': 5052,
#   'joy_tweet': 824,
#   'awe_tweet': 82048,
#   'sad_tweet': 528},
#  'Docklands': {'total_tweet': 11843,
#   'anger_tweet': 277,
#   'amusement_tweet': 2182,
#   'fear_tweet': 190,
#   'indifference_tweet': 584,
#   'joy_tweet': 65,
#   'awe_tweet': 8041,
#   'sad_tweet': 89},
#  'Southbank': {'total_tweet': 29511,
#   'anger_tweet': 427,
#   'amusement_tweet': 5024,
#   'fear_tweet': 326,
#   'indifference_tweet': 1897,
#   'joy_tweet': 213,
#   'awe_tweet': 20527,
#   'sad_tweet': 169},
#  'East Melbourne': {'total_tweet': 20619,
#   'anger_tweet': 382,
#   'amusement_tweet': 3681,
#   'fear_tweet': 252,
#   'indifference_tweet': 870,
#   'joy_tweet': 208,
#   'awe_tweet': 14223,
#   'sad_tweet': 523},
#  'Kensington': {'total_tweet': 15759,
#   'anger_tweet': 22,
#   'amusement_tweet': 465,
#   'fear_tweet': 13748,
# ...

# %%
with open("pie_chart.json", "w") as f:
    json.dump(pie_dict, f)

# %% [markdown]
# # BAR-CHART

# %%
bar_dict = {}
region_dict = {"Melbourne": "206041122",
               "Docklands": "206041118",
               "Southbank": "206041126",
               "East Melbourne": "206041119",
               "Kensington": "206041121"}

for region, code in region_dict.items():
    out_region = out_dict[code]
    bar_dict[region] = {"total_tweet": int(out_region["total_tweet"]),
                        "positive_tweet": int(out_region["positive_tweet"]),
                        "negative_tweet": int(out_region["negative_tweet"]),
                        "neutral_tweet": int(out_region["neutral_tweet"])}

# %%
bar_dict
# Out:
# {'Melbourne': {'total_tweet': 117260,
#   'positive_tweet': 41588,
#   'negative_tweet': 9735,
#   'neutral_tweet': 65937},
#  'Docklands': {'total_tweet': 11843,
#   'positive_tweet': 4148,
#   'negative_tweet': 1101,
#   'neutral_tweet': 6594},
#  'Southbank': {'total_tweet': 29511,
#   'positive_tweet': 10872,
#   'negative_tweet': 2713,
#   'neutral_tweet': 15926},
#  'East Melbourne': {'total_tweet': 20619,
#   'positive_tweet': 7592,
#   'negative_tweet': 2012,
#   'neutral_tweet': 11015},
#  'Kensington': {'total_tweet': 15759,
#   'positive_tweet': 2350,
#   'negative_tweet': 9032,
#   'neutral_tweet': 4377}}

# %% [markdown]
# # WORD CLOUD

# %%
# !pip3 install pillow      # image reading
# !pip3 install wordcloud

# Start with loading all necessary libraries
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
% matplotlib inline
from collections import Counter
import random
# Out:
# ...
# WARNING: You are using pip version 19.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 19.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
word_freq = dict(Counter(big_twitter["anger_word_freq"]) + Counter(big_twitter["annoyance_word_freq"]) +
                 Counter(twitter["anger_word_freq"]) + Counter(twitter["annoyance_word_freq"]) +
                 Counter(richard_db["anger_word_freq"]) + Counter(richard_db["annoyance_word_freq"]))

# %%
stopwords = set(STOPWORDS)
stopwords.update(["st", "rd", "lane", "timeline", "vic", "melbourne", 
                  "victoria", "street", "australia", "left", "right",
                  "closed", "e", "en"])

# %%
def grey_color_func(word, font_size, position, orientation, random_state=None,
                    **kwargs):
    return "hsl(0, 0%%, %d%%)" % random.randint(60, 100)

# %%
for word in stopwords:
    if word in word_freq:
        word_freq.pop(word)

wordcloud = WordCloud(width=3000, height=1500, max_font_size=350, max_words=100, background_color="black")
cloud = wordcloud.generate_from_frequencies(word_freq)

# %%
# store default colored image
plt.imshow(cloud.recolor(color_func=grey_color_func, random_state=3),
           interpolation="bilinear")
# plt.imshow(cloud, interpolation="bilinear")
cloud.to_file("result.png")
plt.axis("off")
plt.show()

# %% [markdown]
# # Polarity and Aurin

# %%
combined_df.head()
# Out:
#   sa2_main16  wrath_rate(%)  negative_rate(%)  work_overtime(%)  \
# 0  208031190       7.410423         15.960912         27.042432
# 1  206061137       3.946765          9.476824         33.103104
# 2  211041270       8.017817         16.369710         22.898810
# 3  212051322       6.414585         12.964213         19.700187
# 4  206041117      10.341129         10.180219         23.791040
#
#    hl_p_homeless_tot  unemp_rate(%)  complete_y12_rate(%)  death_rate(%)  \
# 0                 18       3.501281             66.613924            4.2
# 1                 67       3.810356             77.285290            3.9
# 2                 56       3.709176             68.923625            3.6
# 3                 45       4.493137             72.823668            4.1
# 4                129       8.639594             78.495526            5.0
#
#    population  median_age  median_aud_2014_15
# 0     13695.0        40.9               153.0
# 1     22350.0        31.8               240.0
# ...

# %%
combined_df["wrath_rank"] = combined_df['wrath_rate(%)'].rank(method='dense', ascending=False)
combined_df["negative_rank"] = combined_df['negative_rate(%)'].rank(method='dense', ascending=False)
combined_df["work_overtime_rank"] = combined_df['work_overtime(%)'].rank(method='dense', ascending=False)
combined_df["homeless_rank"] = combined_df['hl_p_homeless_tot'].rank(method='dense', ascending=False)
combined_df["unemp_rank"] = combined_df['unemp_rate(%)'].rank(method='dense', ascending=False)
combined_df["complete_y12_rank"] = combined_df['complete_y12_rate(%)'].rank(method='dense', ascending=False)
combined_df["death_rank"] = combined_df['death_rate(%)'].rank(method='dense', ascending=False)
combined_df["population_rank"] = combined_df['population'].rank(method='dense', ascending=False)
combined_df["age_rank"] = combined_df['median_age'].rank(method='dense', ascending=False)
combined_df["income_rank"] = combined_df['median_aud_2014_15'].rank(method='dense', ascending=False)

# %%
df1.head()
# Out:
#    amusement_tweet  anger_tweet  annoyance_tweet  awe_tweet  fear_tweet  \
# 0              281           40               51        749          20
# 1             2061          169              175       5610          56
# 2              254           31               41        479          12
# 3              267           33               62        987          15
# 4             1750          813              151       5947          71
#
#    indifference_tweet  joy_tweet  negative_tweet  neutral_tweet sa2_main16  \
# 0                  58          6             196            594  208031190
# 1                 461         44             826           4139  206061137
# 2                  55          4             147            430  211041270
# 3                  72         20             192            755  212051322
# 4                 350         59             949           5128  206041117
#
#    sad_tweet  total_tweet
# 0          4         1228
# 1         63         8716
# ...

# %%
df1["total_rank"] = df1['total_tweet'].rank(method='dense', ascending=False)

# %%
combined_df.head()
# Out:
#   sa2_main16  wrath_rate(%)  negative_rate(%)  work_overtime(%)  \
# 0  208031190       7.410423         15.960912         27.042432
# 1  206061137       3.946765          9.476824         33.103104
# 2  211041270       8.017817         16.369710         22.898810
# 3  212051322       6.414585         12.964213         19.700187
# 4  206041117      10.341129         10.180219         23.791040
#
#    hl_p_homeless_tot  unemp_rate(%)  complete_y12_rate(%)  death_rate(%)  \
# 0                 18       3.501281             66.613924            4.2
# 1                 67       3.810356             77.285290            3.9
# 2                 56       3.709176             68.923625            3.6
# 3                 45       4.493137             72.823668            4.1
# 4                129       8.639594             78.495526            5.0
#
#    population  median_age     ...       wrath_rank  negative_rank  \
# 0     13695.0        40.9     ...             74.0           48.0
# ...

# %%
df_polar1 = pd.DataFrame.from_dict(big_twitter_polarity, orient="index", columns=["polarity"])
df_polar2 = pd.DataFrame.from_dict(twitter_polarity, orient="index", columns=["polarity"])
df_polar3 = pd.DataFrame.from_dict(richard_db_polarity, orient="index", columns=["polarity"])

# %%
combined_polar = df_polar1
combined_polar["polarity"] = df_polar1["polarity"] + df_polar2["polarity"] + df_polar3["polarity"]

# %%
combined_polar["polarity_rank"] = combined_polar['polarity'].rank(method='dense', ascending=False)

# %%
combined_polar.head()
# Out:
#              polarity  polarity_rank
# 210051249  181.077740           91.0
# 212021295   34.844377          273.0
# 209011204   36.018322          271.0
# 212031300  101.377096          163.0
# 206021112  320.516394           42.0

# %%
out_dict = {}
code_ls = combined_df["sa2_main16"].values
for code in code_ls:
    out_region_dict = defaultdict(int)
    # polarity
    out_region_dict["polarity"] += big_twitter_polarity.get(code,0) + twitter_polarity.get(code,0) + richard_db_polarity.get(code,0)
    out_region_dict["polarity"] /= twitter["total_info"].get(code,0) + big_twitter["total_info"].get(code,0) + richard_db["total_info"].get(code,0)
    out_region_dict["polarity_rank"] = int(combined_polar.fillna(0).loc[code,"polarity_rank"])
    
    # aurin
    row = combined_df[combined_df["sa2_main16"] == code]
    df1_row = df1[df1["sa2_main16"] == code]
    out_region_dict["total_tweet"] = df1_row["total_tweet"].fillna(0).values[0]
    out_region_dict["wrath_rate"] = row["wrath_rate(%)"].fillna(0).values[0]
    out_region_dict["negative_rate"] = row["negative_rate(%)"].fillna(0).values[0]
    out_region_dict["work_overtime"] = row["work_overtime(%)"].fillna(0).values[0]
    out_region_dict["homeless"] = row["hl_p_homeless_tot"].fillna(0).values[0]
    out_region_dict["unemp_rate"] = row["unemp_rate(%)"].fillna(0).values[0]
    out_region_dict["complete_y12_rate"] = row["complete_y12_rate(%)"].fillna(0).values[0]
    out_region_dict["death_rate"] = row["death_rate(%)"].fillna(0).values[0]
    out_region_dict["population"] = row["population"].fillna(0).values[0]
    out_region_dict["median_age"] = row["median_age"].fillna(0).values[0]
    out_region_dict["median_income"] = row["median_aud_2014_15"].fillna(0).values[0]
    
    # rank
    out_region_dict["total_tweet_rank"] = df1_row["total_rank"].fillna(0).values[0]
    out_region_dict["wrath_rate_rank"] = row["wrath_rank"].fillna(0).values[0]
    out_region_dict["negative_rate_rank"] = row["negative_rank"].fillna(0).values[0]
    out_region_dict["work_overtime_rank"] = row["work_overtime_rank"].fillna(0).values[0]
    out_region_dict["homeless_rank"] = row["homeless_rank"].fillna(0).values[0]
    out_region_dict["unemp_rate_rank"] = row["unemp_rank"].fillna(0).values[0]
    out_region_dict["complete_y12_rate_rank"] = row["complete_y12_rank"].fillna(0).values[0]
    out_region_dict["death_rate_rank"] = row["death_rank"].fillna(0).values[0]
    out_region_dict["population_rank"] = row["population_rank"].fillna(0).values[0]
    out_region_dict["median_age_rank"] = row["age_rank"].fillna(0).values[0]
    out_region_dict["median_income_rank"] = row["income_rank"].fillna(0).values[0]
    
    out_dict[code] = out_region_dict

# %% [markdown]
# # Update DB

# %%
import couchdb

# %%
server = couchdb.Server(url="http://admin:123qweasd@45.113.233.232:5984/")
db = server["homeless_json"]
doc = db["ff4be0927955452a280785783d00c807"]

# %%
new_features = []
for feature in doc["features"]:
    properties = feature["properties"]
    code = properties["sa2_main16"]
    if code not in out_dict:
        properties["polarity"] = 0
        properties["total_tweet"] = 0
        properties["wrath_rate"] = 0
        properties["negative_rate"] = 0
        properties["work_overtime"] = 0
        properties["homeless"] = 0
        properties["unemp_rate"] = 0
        properties["complete_y12_rate"] = 0
        properties["death_rate"] = 0 
        properties["population"] = 0 
        properties["median_age"] = 0 
        properties["median_income"] = 0 
        continue
    properties["polarity"] = out_dict[code]["polarity"]
    properties["total_tweet"] = int(out_dict[code]["total_tweet"])
    properties["wrath_rate"] = out_dict[code]["wrath_rate"]
    properties["negative_rate"] = out_dict[code]["negative_rate"]
    properties["work_overtime"] = out_dict[code]["work_overtime"]
    properties["homeless"] = int(out_dict[code]["homeless"])
    properties["unemp_rate"] = out_dict[code]["unemp_rate"]
    properties["complete_y12_rate"] = out_dict[code]["complete_y12_rate"]
    properties["death_rate"] = out_dict[code]["death_rate"]
    properties["population"] = int(out_dict[code]["population"])
    properties["median_age"] = out_dict[code]["median_age"]
    properties["median_income"] = out_dict[code]["median_income"]
    
    properties["polarity_rank"] = int(out_dict[code]["polarity_rank"])
    properties["total_tweet_rank"] = int(out_dict[code]["total_tweet_rank"])
    properties["wrath_rate_rank"] = int(out_dict[code]["wrath_rate_rank"])
    properties["negative_rate_rank"] = int(out_dict[code]["negative_rate_rank"])
    properties["work_overtime_rank"] = int(out_dict[code]["work_overtime_rank"])
    properties["homeless_rank"] = int(out_dict[code]["homeless_rank"])
    properties["unemp_rate_rank"] = int(out_dict[code]["unemp_rate_rank"])
    properties["complete_y12_rank"] = int(out_dict[code]["complete_y12_rate_rank"])
    properties["death_rate_rank"] = int(out_dict[code]["death_rate_rank"])
    properties["population_rank"] = int(out_dict[code]["population_rank"])
    properties["median_age_rank"] = int(out_dict[code]["median_age_rank"])
    properties["median_income_rank"] = int(out_dict[code]["median_income_rank"])
    
    feature["properties"] = properties
    new_features.append(feature)

# %%
doc["features"] = new_features

# %%
db["ff4be0927955452a280785783d00c807"] = doc

# %% [markdown]
# # Scatter Plot and Correlations

# %%
combined_df.head()
# Out:
#   sa2_main16  wrath_rate(%)  negative_rate(%)  work_overtime(%)  \
# 0  208031190       7.410423         15.960912         27.042432
# 1  206061137       3.946765          9.476824         33.103104
# 2  211041270       8.017817         16.369710         22.898810
# 3  212051322       6.414585         12.964213         19.700187
# 4  206041117      10.341129         10.180219         23.791040
#
#    hl_p_homeless_tot  unemp_rate(%)  complete_y12_rate(%)  death_rate(%)  \
# 0                 18       3.501281             66.613924            4.2
# 1                 67       3.810356             77.285290            3.9
# 2                 56       3.709176             68.923625            3.6
# 3                 45       4.493137             72.823668            4.1
# 4                129       8.639594             78.495526            5.0
#
#    population  median_age     ...       wrath_rank  negative_rank  \
# 0     13695.0        40.9     ...             74.0           48.0
# ...

# %%
combined_df.corr().head()
# Out:
#                    wrath_rate(%)  negative_rate(%)  work_overtime(%)  \
# wrath_rate(%)           1.000000         -0.107345         -0.310599
# negative_rate(%)       -0.107345          1.000000         -0.005402
# work_overtime(%)       -0.310599         -0.005402          1.000000
# hl_p_homeless_tot       0.069079         -0.002122         -0.236252
# unemp_rate(%)           0.230441          0.041415         -0.666690
#
#                    hl_p_homeless_tot  unemp_rate(%)  complete_y12_rate(%)  \
# wrath_rate(%)               0.069079       0.230441             -0.076227
# negative_rate(%)           -0.002122       0.041415              0.023012
# work_overtime(%)           -0.236252      -0.666690              0.353207
# hl_p_homeless_tot           1.000000       0.488074              0.038186
# unemp_rate(%)               0.488074       1.000000              0.028254
#
#                    death_rate(%)  population  median_age  median_aud_2014_15  \
# ...

# %%
combined_df.corr().iloc[0, 1:]
# Out:
# negative_rate(%)       -0.107345
# work_overtime(%)       -0.310599
# hl_p_homeless_tot       0.069079
# unemp_rate(%)           0.230441
# complete_y12_rate(%)   -0.076227
# death_rate(%)           0.076944
# population             -0.001023
# median_age             -0.036280
# median_aud_2014_15     -0.104909
# wrath_rank             -0.936886
# negative_rank          -0.062835
# work_overtime_rank      0.324939
# homeless_rank          -0.156364
# unemp_rank             -0.214222
# complete_y12_rank       0.083834
# death_rank             -0.079040
# population_rank        -0.008349
# age_rank                0.046896
# income_rank             0.101301
# Name: wrath_rate(%), dtype: float64

# %%
def get_xy(data):
    x = []
    y = []
    for region in data:
        x.append(region[0])
        y.append(region[1])
    return x,y

# %%
scatter1 = get_xy(combined_df.iloc[:, [1,3]].dropna().values)
scatter2 = get_xy(combined_df.iloc[:, [1,4]].dropna().values)
scatter3 = get_xy(combined_df.iloc[:, [1,5]].dropna().values)
scatter4 = get_xy(combined_df.iloc[:, [1,6]].dropna().values)
scatter5 = get_xy(combined_df.iloc[:, [1,7]].dropna().values)
scatter6 = get_xy(combined_df.iloc[:, [1,8]].dropna().values)
scatter7 = get_xy(combined_df.iloc[:, [1,9]].dropna().values)
scatter8 = get_xy(combined_df.iloc[:, [1,10]].dropna().values)

# %%
scatter_plots = {
    "work_overtime": {
        "x": scatter1[0],
        "y": scatter1[1],
        "corr": combined_df.corr().iloc[0, 2]
    },
    "homeless": {
        "x": scatter2[0],
        "y": scatter2[1],
        "corr": combined_df.corr().iloc[0, 3]
    },
    "unemp": {
        "x": scatter3[0],
        "y": scatter3[1],
        "corr": combined_df.corr().iloc[0, 4]
    },
    "complete_y12": {
        "x": scatter4[0],
        "y": scatter4[1],
        "corr": combined_df.corr().iloc[0, 5]
    },
    "death_rate": {
        "x": scatter5[0],
        "y": scatter5[1],
        "corr": combined_df.corr().iloc[0, 6]
    },
    "population": {
        "x": scatter6[0],
        "y": scatter6[1],
        "corr": combined_df.corr().iloc[0, 7]
    },
    "median_age": {
        "x": scatter7[0],
        "y": scatter7[1],
        "corr": combined_df.corr().iloc[0, 8]
    },
    "income": {
        "x": scatter8[0],
        "y": scatter8[1],
        "corr": combined_df.corr().iloc[0, 9]
    }
}

# %%
scatter_plots
# Out:
# {'work_overtime': {'x': [7.41042345276873,
#    3.9467645709040844,
#    8.017817371937639,
#    6.414584740040513,
#    10.341128513194594,
#    6.896551724137931,
#    4.868244752121482,
#    3.4337261748872403,
#    10.606060606060606,
#    11.670480549199084,
#    7.084785133565622,
#    10.195227765726681,
#    4.955621301775148,
#    3.048780487804878,
#    0.9759202291290971,
#    5.653252778077462,
#    12.473118279569892,
#    2.5168090132654917,
#    10.204081632653061,
#    5.939653124257544,
#    3.2496357290501847,
#    5.676442762535478,
#    3.0988274706867673,
#    5.688888888888889,
#    6.553398058252427,
#    4.861111111111112,
#    3.7469586374695862,
#    5.284015852047556,
#    8.264462809917356,
#    7.60324199150907,
#    3.6211699164345403,
#    4.696132596685083,
#    5.337078651685393,
#    8.721215090641843,
#    5.6583818085668955,
#    5.118411000763942,
#    4.129021362830364,
#    5.396618985695708,
#    4.925911093311974,
#    8.810240963855422,
# ...

# %% [markdown]
# # PCA and Linear Regression

# %%
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
pca = PCA(n_components=3)

# %%
combined_df.head()
# Out:
#   sa2_main16  wrath_rate(%)  negative_rate(%)  work_overtime(%)  \
# 0  208031190       7.410423         15.960912         27.042432
# 1  206061137       3.946765          9.476824         33.103104
# 2  211041270       8.017817         16.369710         22.898810
# 3  212051322       6.414585         12.964213         19.700187
# 4  206041117      10.341129         10.180219         23.791040
#
#    hl_p_homeless_tot  unemp_rate(%)  complete_y12_rate(%)  death_rate(%)  \
# 0                 18       3.501281             66.613924            4.2
# 1                 67       3.810356             77.285290            3.9
# 2                 56       3.709176             68.923625            3.6
# 3                 45       4.493137             72.823668            4.1
# 4                129       8.639594             78.495526            5.0
#
#    population  median_age     ...       wrath_rank  negative_rank  \
# 0     13695.0        40.9     ...             74.0           48.0
# ...

# %%
df = combined_df.dropna()
X = df.loc[:,"work_overtime(%)": "median_aud_2014_15"].values
pca.fit(X)
X = pca.transform(X)
y = df["wrath_rate(%)"].values

# %%
pca.components_
# Out:
# array([[-8.09682506e-05,  7.43954620e-03,  4.21851908e-05,
#          1.42260089e-04, -2.91489466e-06,  9.99972285e-01,
#         -1.48563661e-04, -1.79627385e-04],
#        [-1.60726566e-02,  9.90000765e-01,  6.78869855e-03,
#         -8.48679183e-03,  3.19902923e-03, -7.39352086e-03,
#         -2.01633827e-02, -1.38023847e-01],
#        [ 5.49546772e-02,  1.39412652e-01, -8.03579878e-03,
#          1.09442745e-01, -6.18536717e-03, -8.67317488e-04,
#          2.85989611e-02,  9.82163375e-01]])

# %%
print(len(X))
print(len(y))
# Out:
# 280
# 280

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
model.score(X, y)
# Out:
# 0.02055429387664476

# %%
# The coefficients
print('Coefficients: \n', model.coef_)
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(model.predict(X), y))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(model.predict(X), y))
# Out:
# Coefficients:
#  [-5.79424718e-06  3.25233808e-03 -4.90799251e-03]
# Mean squared error: 6.23
# Variance score: -46.65

# %%
# # Plot outputs
# plt.scatter(diabetes_X_test, diabetes_y_test,  color='black')
# plt.plot(diabetes_X_test, diabetes_y_pred, color='blue', linewidth=3)

# plt.xticks(())
# plt.yticks(())

# plt.show()

# %%
pca.transform([[1,1,1,1,1,1,1,1]])
# Out:
# array([[-16076.83945874,     68.49138775,   -131.88106818]])

# %%
pc1 = [-8.09682506e-05,  7.43954620e-03,  4.21851908e-05,
         1.42260089e-04, -2.91489466e-06,  9.99972285e-01,
        -1.48563661e-04, -1.79627385e-04]

pc2 = [-1.60726566e-02,  9.90000765e-01,  6.78869855e-03,
        -8.48679183e-03,  3.19902923e-03, -7.39352086e-03,
        -2.01633827e-02, -1.38023847e-01]

pc3 = [ 5.49546772e-02,  1.39412652e-01, -8.03579878e-03,
         1.09442745e-01, -6.18536717e-03, -8.67317488e-04,
         2.85989611e-02,  9.82163375e-01]

# %%
(1 - pca.mean_).dot(pc1)
# Out:
# -16076.839463038847

# %%
# LR

# %%
lr_coefficients = [-5.79424718e-06,  3.25233808e-03, -4.90799251e-03]

# %%
np.array([-16076.83945874, 68.49138775, -131.88106818]).dot(lr_coefficients) + model.intercept_
# Out:
# 7.042691576206429

# %%
model.predict([[-16076.83945874,     68.49138775,   -131.88106818]])
# Out:
# array([7.04269158])

# %%
input_data = combined_df.loc[4, "work_overtime(%)": "median_aud_2014_15"].values

# %%
after_transform = pca.transform([input_data])

# %%
model.predict(after_transform)
# Out:
# array([5.92458931])

# %%
combined_df.head()
# Out:
#   sa2_main16  wrath_rate(%)  negative_rate(%)  work_overtime(%)  \
# 0  208031190       7.410423         15.960912         27.042432
# 1  206061137       3.946765          9.476824         33.103104
# 2  211041270       8.017817         16.369710         22.898810
# 3  212051322       6.414585         12.964213         19.700187
# 4  206041117      10.341129         10.180219         23.791040
#
#    hl_p_homeless_tot  unemp_rate(%)  complete_y12_rate(%)  death_rate(%)  \
# 0                 18       3.501281             66.613924            4.2
# 1                 67       3.810356             77.285290            3.9
# 2                 56       3.709176             68.923625            3.6
# 3                 45       4.493137             72.823668            4.1
# 4                129       8.639594             78.495526            5.0
#
#    population  median_age     ...       wrath_rank  negative_rank  \
# 0     13695.0        40.9     ...             74.0           48.0
# ...

# %%
pca.components_[0]
# Out:
# array([-8.09682506e-05,  7.43954620e-03,  4.21851908e-05,  1.42260089e-04,
#        -2.91489466e-06,  9.99972285e-01, -1.48563661e-04, -1.79627385e-04])

# %%
out_dict = {
    "pca_means": pca.mean_,
    "pc1_coefficients": pca.components_[0],
    "pc2_coefficients": pca.components_[1],
    "pc3_coefficients": pca.components_[2],
    "lr_coefficients": model.coef_,
    "lr_intercept":model.intercept_
}

# %%
out_dict
# Out:
# {'pca_means': array([2.36595300e+01, 7.15142857e+01, 4.12580306e+00, 6.14584249e+01,
#         5.06642857e+00, 1.60777821e+04, 3.69232143e+01, 1.30464286e+02]),
#  'pc1_coefficients': array([-8.09682506e-05,  7.43954620e-03,  4.21851908e-05,  1.42260089e-04,
#         -2.91489466e-06,  9.99972285e-01, -1.48563661e-04, -1.79627385e-04]),
#  'pc2_coefficients': array([-0.01607266,  0.99000077,  0.0067887 , -0.00848679,  0.00319903,
#         -0.00739352, -0.02016338, -0.13802385]),
#  'pc3_coefficients': array([ 5.49546772e-02,  1.39412652e-01, -8.03579878e-03,  1.09442745e-01,
#         -6.18536717e-03, -8.67317488e-04,  2.85989611e-02,  9.82163375e-01]),
#  'lr_coefficients': array([-5.79424718e-06,  3.25233808e-03, -4.90799251e-03]),
#  'lr_intercept': 6.079509951139702}
